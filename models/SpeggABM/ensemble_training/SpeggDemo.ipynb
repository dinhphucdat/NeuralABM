# %% [markdown]
# # Show the training data for sPEGG

# %%
import os
os.chdir(os.path.dirname(os.getcwd()))

# %%
from ensemble_training import generate_training_data

# %%
training_data = generate_training_data(
    {
        'nloci': 3,
        'pos_loci_interest': 0,
        'pos_col_allele_interest': 5,
        'output_sep': "\t"
    }
)
# Out:
# Using workflow specific profile workflow-profiles/default for setting default command line arguments.
# snpArcher v2 is tested with Snakemake >=9, but this run is using Snakemake 0.0.0. Checkpoint behavior and other workflow features may be unreliable on older versions.
# Assuming unrestricted shared filesystem usage.
# host: System-Product-Name
# Building DAG of jobs...
# Your conda installation is not configured to use strict channel priorities. This is however important for having robust and correct environments (for details, see https://conda-forge.org/docs/user/tipsandtricks.html). Please consider to configure strict priorities by executing 'conda config --set channel_priority strict'.
# Nothing to be done (all requested files are present and up to date).
# Using workflow specific profile workflow-profiles/default for setting default command line arguments.
# ...

# %%
print(training_data)
# Out:
# tensor([[0.6111],
#         [0.5500],
#         [0.4500],
#         [0.1000],
#         [0.3750],
#         [0.4500],
#         [0.3158],
#         [0.4375],
#         [0.1000],
#         [0.4000]])
